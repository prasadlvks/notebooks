# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cancer = load_breast_cancer()

# %%
df=pd.DataFrame(cancer.data, columns=cancer.feature_names)
df.shape
# Out:
# (569, 30)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# 0                 0.07871           ...                    25.38
# 1                 0.05667           ...                    24.99
# 2                 0.05999           ...                    23.57
# 3                 0.09744           ...                    14.91
# 4                 0.05883           ...                    22.54
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# 0          17.33           184.60      2019.0            0.1622
# 1          23.41           158.80      1956.0            0.1238
# 2          25.53           152.50      1709.0            0.1444
# 3          26.50            98.87       567.7            0.2098
# 4          16.67           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 30 columns]

# %%
df1=pd.DataFrame(cancer.target)
df1.columns=['target']
df1.head()
# Out:
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data=df.append(df1,sort=True)
data.head()
# Out:
#    area error  compactness error  concave points error  concavity error  \
# 0      153.40            0.04904               0.01587          0.05373
# 1       74.08            0.01308               0.01340          0.01860
# 2       94.03            0.04006               0.02058          0.03832
# 3       27.23            0.07458               0.01867          0.05661
# 4       94.44            0.02461               0.01885          0.05688
#
#    fractal dimension error  mean area  mean compactness  mean concave points  \
# 0                 0.006193     1001.0           0.27760              0.14710
# 1                 0.003532     1326.0           0.07864              0.07017
# 2                 0.004571     1203.0           0.15990              0.12790
# 3                 0.009208      386.1           0.28390              0.10520
# 4                 0.005115     1297.0           0.13280              0.10430
#
#    mean concavity  mean fractal dimension      ...        worst area  \
# 0          0.3001                 0.07871      ...            2019.0
# 1          0.0869                 0.05667      ...            1956.0
# 2          0.1974                 0.05999      ...            1709.0
# 3          0.2414                 0.09744      ...             567.7
# 4          0.1980                 0.05883      ...            1575.0
#
#    worst compactness  worst concave points  worst concavity  \
# 0             0.6656                0.2654           0.7119
# 1             0.1866                0.1860           0.2416
# 2             0.4245                0.2430           0.4504
# 3             0.8663                0.2575           0.6869
# 4             0.2050                0.1625           0.4000
#
#    worst fractal dimension  worst perimeter  worst radius  worst smoothness  \
# 0                  0.11890           184.60         25.38            0.1622
# 1                  0.08902           158.80         24.99            0.1238
# 2                  0.08758           152.50         23.57            0.1444
# 3                  0.17300            98.87         14.91            0.2098
# 4                  0.07678           152.20         22.54            0.1374
#
#    worst symmetry  worst texture
# 0          0.4601          17.33
# 1          0.2750          23.41
# 2          0.3613          25.53
# 3          0.6638          26.50
# 4          0.2364          16.67
#
# [5 rows x 31 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn')
