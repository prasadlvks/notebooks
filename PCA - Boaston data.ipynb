# %%
from sklearn.datasets import load_boston
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
boaston = load_boston()

# %%
type(boaston)
# Out:
# sklearn.utils.Bunch

# %%
boaston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boaston.target.shape
# Out:
# (506,)

# %%
X, y = boaston.data, boaston.target

# %%
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
X = pd.DataFrame(boaston.data,columns=boaston.feature_names)

# %%
X.head(4)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94

# %%
pca = PCA(n_components=3)
pca.fit(boaston.data)
boaston_pca = pca.transform(boaston.data)

# %%
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
boaston_pca.shape
# Out:
# (506, 3)

# %%
boaston_pca
# Out:
# array([[-119.81884272,   -5.56005586,   -3.17269264],
#        [-168.89015548,   10.11620863,  -30.78188677],
#        [-169.31170747,   14.0805323 ,  -16.75362821],
#        ...,
#        [-138.38716306,    0.9380922 ,  -37.28518133],
#        [-137.50517338,    4.2518251 ,  -35.98834188],
#        [-139.19033295,    1.00906423,  -29.77243231]])

# %%
plt.scatter(C[:,0],C[:,1], s=2**7, edgecolors='white', alpha=.85, cmap='autumn', c='red')

# %%
plt.scatter(C[:,11],C[:,12], s=2**7, cmap='autumn', edgecolors='white', alpha=.85, c='g')

# %%
C[:,0]
# Out:
# array([-2.09829747e+00, -1.45725167e+00, -2.07459756e+00, -2.61150357e+00,
#        -2.45818501e+00, -2.21485151e+00, -1.35888109e+00, -8.42044613e-01,
#        -1.79928278e-01, -1.07418411e+00, -9.09411525e-01, -1.24365506e+00,
#        -1.46289731e+00, -7.35774355e-01, -3.60017517e-01, -7.20059064e-01,
#        -1.10077658e+00, -1.50712974e-01, -3.50566848e-01, -3.03610155e-01,
#         5.27793187e-01, -7.01300294e-02,  1.29156051e-01,  3.40847378e-01,
#         3.66500202e-02,  2.36240719e-01, -4.71253733e-02,  1.80430336e-01,
#        -2.59457105e-01, -3.65687064e-01,  4.79684821e-01,  1.21602512e-02,
#         8.31254584e-01,  3.80290824e-01,  6.44874748e-01, -8.24874720e-01,
#        -7.59481376e-01, -1.22708516e+00, -1.30157468e+00, -3.46451399e+00,
#        -3.74850781e+00, -2.71464486e+00, -2.46427252e+00, -2.43009528e+00,
#        -1.91631315e+00, -1.77292040e+00, -1.63496624e+00, -9.96168568e-01,
# ...
