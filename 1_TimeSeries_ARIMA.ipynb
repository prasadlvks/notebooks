# %%
from pandas import read_csv
from matplotlib import pyplot

# %%
series = read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv', header=0, index_col=0)
series.plot()
pyplot.show()

# %%
y = dot_product(ar_coefficients, lags) + dot_product(ma_coefficients, residuals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a181a28878d6> in <module>
# ----> 1 y = dot_product(ar_coefficients, lags) + dot_product(ma_coefficients, residuals)
#
# NameError: name 'dot_product' is not defined

# %%
def predict(coef, history):
    yhat = 0.0
    for i in range(1, len(coef)+1):
        yhat += coef[i-1] * history[-i]
    return yhat

# %%
model = ARIMA(history, order=(k,0,0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-348b7dedb7da> in <module>
# ----> 1 model = ARIMA(history, order=(k,0,0))
#
# NameError: name 'ARIMA' is not defined
