# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'])

# %%
df.head(10)
# Out:
#         date     value
# 0 1991-07-01  3.526591
# 1 1991-08-01  3.180891
# 2 1991-09-01  3.252221
# 3 1991-10-01  3.611003
# 4 1991-11-01  3.565869
# 5 1991-12-01  4.306371
# 6 1992-01-01  5.088335
# 7 1992-02-01  2.814520
# 8 1992-03-01  2.985811
# 9 1992-04-01  3.204780

# %%
plt.figure(figsize=(16,5), dpi=100)
plt.plot(df.date, df.value, color='tab:red')
plt.gca().set(title='Monthly anti-diabetic drug sales in Australia from 1992 to 2008.', xlabel='Date', ylabel='Value')
plt.show()

# %%
plot_acf(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-fa2a95680ced> in <module>
# ----> 1 plot_acf(df)
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/graphics/tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, title, zero, vlines_kwargs, **kwargs)
#     132     else:
#     133         acf_x, confint = acf(x, nlags=nlags, alpha=alpha, fft=fft,
# --> 134                              unbiased=unbiased)
#     135
#     136     _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines,
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in acf(x, unbiased, nlags, qstat, fft, alpha, missing)
#     473     """
#     474     nobs = len(x)  # should this shrink for missing='drop' and NaNs in x?
# --> 475     avf = acovf(x, unbiased=unbiased, demean=True, fft=fft, missing=missing)
#     476     acf = avf[:nlags + 1] / avf[0]
#     477     if not (qstat or alpha):
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in acovf(x, unbiased, demean, fft, missing)
#     327     x = np.squeeze(np.asarray(x))
#     328     if x.ndim > 1:
# --> 329         raise ValueError("x must be 1d. Got %d dims." % x.ndim)
#     330
#     331     missing = missing.lower()
#
# ValueError: x must be 1d. Got 2 dims.

# %%
ARIMAModel=ARIMA(df,order=(5,2,1)).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4a918c850392> in <module>
# ----> 1 ARIMAModel=ARIMA(df,order=(5,2,1)).fit()
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     994         else:
#     995             mod = super(ARIMA, cls).__new__(cls)
# --> 996             mod.__init__(endog, order, exog, dates, freq, missing)
#     997             return mod
#     998
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1013             # in the predict method
#    1014             raise ValueError("d > 2 is not supported")
# -> 1015         super(ARIMA, self).__init__(endog, (p, q), exog, dates, freq, missing)
#    1016         self.k_diff = d
#    1017         self._first_unintegrate = unintegrate_levels(self.endog[:d], d)
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     433     def __init__(self, endog, order, exog=None, dates=None, freq=None,
#     434                  missing='none'):
# --> 435         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     436         exog = self.data.exog  # get it after it's gone through processing
#     437         _check_estimable(len(self.endog), sum(order))
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#      53                  missing='none', **kwargs):
#      54         super(TimeSeriesModel, self).__init__(endog, exog, missing=missing,
# ---> 55                                               **kwargs)
#      56
#      57         # Date handling in indexes
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# ~/anaconda3_501/lib/python3.6/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     472         exog = exog if exog is None else np.asarray(exog)
#     473         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 474             raise ValueError("Pandas data cast to numpy dtype of object. "
#     475                              "Check input data with np.asarray(data).")
#     476         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
