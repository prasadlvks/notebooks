# %%
import requests
resp = requests.get("http://127.0.0.1:8000/irisapp/api/flower/",params = { "sepel_length": 7.7,"sepel_width": 2.3,"petal_length": 6.7,"petal_width": 2.1})
resp
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
