# %%
import pandas as pd

# %%
ipl_auction_df = pd.read_csv('IPL IMB381IPL2013.csv')
pd.set_option('display.max_columns', 7)
ipl_auction_df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE    ...     AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2    ...             2009      50000      50000
# 1       2  Abdur Razzak    2    ...             2008      50000      50000
# 2       3   Agarkar, AB    2    ...             2008     200000     350000
# 3       4     Ashwin, R    1    ...             2011     100000     850000
# 4       5  Badrinath, S    2    ...             2011     100000     800000
#
# [5 rows x 26 columns]

# %%
list(ipl_auction_df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl_auction_df.head().transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B                 0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
ipl_auction_df.shape
# Out:
# (130, 26)

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
# Sl.NO.           130 non-null int64
# PLAYER NAME      130 non-null object
# AGE              130 non-null int64
# COUNTRY          130 non-null object
# TEAM             130 non-null object
# PLAYING ROLE     130 non-null object
# T-RUNS           130 non-null int64
# T-WKTS           130 non-null int64
# ODI-RUNS-S       130 non-null int64
# ODI-SR-B         130 non-null float64
# ODI-WKTS         130 non-null int64
# ODI-SR-BL        130 non-null float64
# CAPTAINCY EXP    130 non-null int64
# RUNS-S           130 non-null int64
# HS               130 non-null int64
# AVE              130 non-null float64
# SR-B             130 non-null float64
# SIXERS           130 non-null int64
# RUNS-C           130 non-null int64
# WKTS             130 non-null int64
# AVE-BL           130 non-null float64
# ECON             130 non-null float64
# ...

# %%
ipl_auction_df[0:5]​ipl_auction_df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE    ...     AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2    ...             2009      50000      50000
# 1       2  Abdur Razzak    2    ...             2008      50000      50000
# 2       3   Agarkar, AB    2    ...             2008     200000     350000
# 3       4     Ashwin, R    1    ...             2011     100000     850000
# 4       5  Badrinath, S    2    ...             2011     100000     800000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE    ...     AUCTION YEAR BASE PRICE SOLD PRICE
# 125     126     Yadav, AS    2    ...             2010      50000     750000
# 126     127   Younis Khan    2    ...             2008     225000     225000
# 127     128  Yuvraj Singh    2    ...             2011     400000    1800000
# 128     129   Zaheer Khan    2    ...             2008     200000     450000
# 129     130    Zoysa, DNT    2    ...             2008     100000     110000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df[['PLAYER NAME','COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
ipl_auction_df.iloc[0:5,0:3]
# Out:
#    Sl.NO.   PLAYER NAME  AGE
# 0       1   Abdulla, YA    2
# 1       2  Abdur Razzak    2
# 2       3   Agarkar, AB    2
# 3       4     Ashwin, R    1
# 4       5  Badrinath, S    2

# %%
ipl_auction_df['COUNTRY'].value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# ZIM     1
# BAN     1
# Name: COUNTRY, dtype: int64

# %%
ipl_auction_df['COUNTRY'].value_counts(normalize=True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# ZIM     0.769231
# BAN     0.769231
# Name: COUNTRY, dtype: float64

# %%
pd.crosstab(ipl_auction_df['AGE'],ipl_auction_df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
ipl_auction_df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE', ascending=False)[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000

# %%
#create a new column
ipl_auction_df['premium'] = ipl_auction_df['SOLD PRICE'] - ipl_auction_df['BASE PRICE']

# %%
ipl_auction_df[['PLAYER NAME','SOLD PRICE','BASE PRICE','premium']][0:5]
# Out:
#     PLAYER NAME  SOLD PRICE  BASE PRICE  premium
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      350000      200000   150000
# 3     Ashwin, R      850000      100000   750000
# 4  Badrinath, S      800000      100000   700000

# %%
ipl_auction_df[['PLAYER NAME','SOLD PRICE','BASE PRICE','premium']].sort_values('premium', ascending=False)[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE  BASE PRICE  premium
# 50        Kohli, V     1800000      150000  1650000
# 113     Tiwary, SS     1600000      100000  1500000
# 127   Yuvraj Singh     1800000      400000  1400000
# 111  Tendulkar, SR     1800000      400000  1400000
# 93       Sehwag, V     1800000      400000  1400000

# %%
ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
ipl_auction_df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
ipl_auction_df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].mean()
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#bar plot
sn.barplot(x='AGE', y='SOLD PRICE', data=ipl_auction_df)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sn.barplot(x='AGE', y='SOLD PRICE', hue='PLAYING ROLE', data=ipl_auction_df)

# %%
plt.hist(ipl_auction_df['SOLD PRICE'])
# Out:
# (array([27., 32., 21., 20., 14.,  7.,  0.,  1.,  4.,  4.]),
#  array([  20000.,  198000.,  376000.,  554000.,  732000.,  910000.,
#         1088000., 1266000., 1444000., 1622000., 1800000.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ipl_auction_df['SOLD PRICE'], bins=20)
# Out:
# (array([16., 11., 16., 16.,  9., 12.,  5., 15.,  8.,  6.,  6.,  1.,  0.,
#          0.,  1.,  0.,  1.,  3.,  0.,  4.]),
#  array([  20000.,  109000.,  198000.,  287000.,  376000.,  465000.,
#          554000.,  643000.,  732000.,  821000.,  910000.,  999000.,
#         1088000., 1177000., 1266000., 1355000., 1444000., 1533000.,
#         1622000., 1711000., 1800000.]),
#  <a list of 20 Patch objects>)

# %%
sn.distplot(ipl_auction_df['SOLD PRICE'])

# %%
sn.boxplot(ipl_auction_df['SOLD PRICE'])

# %%
plt.boxplot(ipl_auction_df['SOLD PRICE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1525ad4b00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1525ae2208>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1525ad49b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1525ae2898>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1525ae2eb8>],
#  'means': []}

# %%
box = plt.boxplot(ipl_auction_df['SOLD PRICE'])

# %%
[item.get_ydata()[0] for item in box['caps']]
# Out:
# [20000.0, 1350000.0]

# %%
[item.get_ydata()[0] for item in box['whiskers']]
# Out:
# [225000.0, 700000.0]

# %%
[item.get_ydata()[0] for item in box['medians']]
# Out:
# [437500.0]

# %%
sn.distplot(ipl_auction_df[ipl_auction_df['CAPTAINCY EXP']==1]['SOLD PRICE'])
sn.distplot(ipl_auction_df[ipl_auction_df['CAPTAINCY EXP']==0]['SOLD PRICE'], color='r')

# %%
sn.boxplot(x='PLAYING ROLE',y='SOLD PRICE',data=ipl_auction_df)

# %%
plt.scatter(ipl_auction_df['SIXERS'],ipl_auction_df['SOLD PRICE'])

# %%
sn.regplot(x='SIXERS',y='SOLD PRICE',data=ipl_auction_df)

# %%
sn.pairplot(ipl_auction_df[['SOLD PRICE','SIXERS']])

# %%
ipl_auction_df[['SOLD PRICE','SIXERS']].corr()
# Out:
#             SOLD PRICE    SIXERS
# SOLD PRICE    1.000000  0.450609
# SIXERS        0.450609  1.000000

# %%
sn.heatmap(ipl_auction_df[['SOLD PRICE','SIXERS']].corr(),annot=True)
